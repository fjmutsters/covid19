# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

# %matplotlib inline

# %%
countries = pd.read_csv('../data/population_by_country_2020.csv')

# %%
countries.head()
# Out:
#   Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                   China         1440297825        0.39 %     5540090
# 1                   India         1382345085        0.99 %    13586631
# 2           United States          331341050        0.59 %     1937734
# 3               Indonesia          274021604        1.07 %     2898047
# 4                Pakistan          221612785        2.00 %     4327022
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0              153          9388211       -348399.0        1.7       38
# 1              464          2973190       -532687.0        2.2       28
# 2               36          9147420        954806.0        1.8       38
# 3              151          1811570        -98955.0        2.3       30
# 4              287           770880       -233379.0        3.6       23
#
#   Urban Pop % World Share
# 0        61 %     18.47 %
# 1        35 %     17.70 %
# ...

# %%
#check India, 1382 million population, 464 P/km2, med age 28, urban pop 35%
countries[countries['Country (or dependency)'] == 'India']
# Out:
#   Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 1                   India         1382345085        0.99 %    13586631
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 1              464          2973190       -532687.0        2.2       28
#
#   Urban Pop % World Share
# 1        35 %     17.70 %

# %%
#check NL, 17 million population, 508 P/km2, med age 43, urban pop 92%
countries[countries['Country (or dependency)'] == 'Netherlands']
# Out:
#    Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 68             Netherlands           17141544        0.22 %       37742
#
#     Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 68              508            33720         16000.0        1.7       43
#
#    Urban Pop % World Share
# 68        92 %      0.22 %

# %%
#what are countries in this dataset?
countries['Country (or dependency)'].unique()
# 235 countries, all 8 populations of our group are in
# Out:
# array(['China', 'India', 'United States', 'Indonesia', 'Pakistan',
#        'Brazil', 'Nigeria', 'Bangladesh', 'Russia', 'Mexico', 'Japan',
#        'Ethiopia', 'Philippines', 'Egypt', 'Vietnam', 'DR Congo',
#        'Turkey', 'Iran', 'Germany', 'Thailand', 'United Kingdom',
#        'France', 'Italy', 'Tanzania', 'South Africa', 'Myanmar', 'Kenya',
#        'South Korea', 'Colombia', 'Spain', 'Uganda', 'Argentina',
#        'Algeria', 'Sudan', 'Ukraine', 'Iraq', 'Afghanistan', 'Poland',
#        'Canada', 'Morocco', 'Saudi Arabia', 'Uzbekistan', 'Peru',
#        'Angola', 'Malaysia', 'Mozambique', 'Ghana', 'Yemen', 'Nepal',
#        'Venezuela', 'Madagascar', 'Cameroon', "Côte d'Ivoire",
#        'North Korea', 'Australia', 'Niger', 'Taiwan', 'Sri Lanka',
#        'Burkina Faso', 'Mali', 'Romania', 'Malawi', 'Chile', 'Kazakhstan',
#        'Zambia', 'Guatemala', 'Ecuador', 'Syria', 'Netherlands',
#        'Senegal', 'Cambodia', 'Chad', 'Somalia', 'Zimbabwe', 'Guinea',
# ...

# %%
countries.info()
#235 countries
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country (or dependency)  235 non-null    object
#  1   Population (2020)        235 non-null    int64
#  2   Yearly Change            235 non-null    object
#  3   Net Change               235 non-null    int64
#  4   Density (P/Km²)          235 non-null    int64
#  5   Land Area (Km²)          235 non-null    int64
#  6   Migrants (net)           201 non-null    float64
#  7   Fert. Rate               235 non-null    object
#  8   Med. Age                 235 non-null    object
#  9   Urban Pop %              235 non-null    object
#  10  World Share              235 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.3+ KB

# %%
#25 biggest countries in world
df1 = countries[['Country (or dependency)', 'Population (2020)']]
df1 = df1.nlargest(25, ['Population (2020)']) 
df1

#India 1382 million, Brazil 213 million, Turkey 84 million, UK 68 million, Italy 60 million
#South Korea, Romania and NL not in 25 biggest countries
# Out:
#    Country (or dependency)  Population (2020)
# 0                    China         1440297825
# 1                    India         1382345085
# 2            United States          331341050
# 3                Indonesia          274021604
# 4                 Pakistan          221612785
# 5                   Brazil          212821986
# 6                  Nigeria          206984347
# 7               Bangladesh          164972348
# 8                   Russia          145945524
# 9                   Mexico          129166028
# 10                   Japan          126407422
# 11                Ethiopia          115434444
# 12             Philippines          109830324
# 13                   Egypt          102659126
# 14                 Vietnam           97490013
# 15                DR Congo           90003954
# 16                  Turkey           84495243
# 17                    Iran           84176929
# 18                 Germany           83830972
# ...

# %%
#plot of 25 biggest countries in the world
fig, ax = plt.subplots(figsize=(16, 6))
plt.xticks(rotation = 45)
sns.barplot(data = df, x = 'Country (or dependency)', y = 'Population (2020)')

# %%
#check interestings stats of Brazil
countries[countries['Country (or dependency)'] == 'Brazil']
#213 million population, 25 P/km2, med age 33, urban pop 88%
# Out:
#   Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 5                  Brazil          212821986        0.72 %     1509890
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 5               25          8358140         21200.0        1.7       33
#
#   Urban Pop % World Share
# 5        88 %      2.73 %

# %%
#check interestings stats of Turkey
countries[countries['Country (or dependency)'] == 'Turkey']
#84 million population, 110 P/km2, med age 32, urban pop 76%
# Out:
#    Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 16                  Turkey           84495243        1.09 %      909452
#
#     Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 16              110           769630        283922.0        2.1       32
#
#    Urban Pop % World Share
# 16        76 %      1.08 %

# %%
#check interestings stats of United Kingdom
countries[countries['Country (or dependency)'] == 'United Kingdom']
#68 million population, 281 P/km2, med age 40, urban pop 83%
# Out:
#    Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 20          United Kingdom           67948282        0.53 %      355839
#
#     Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 20              281           241930        260650.0        1.8       40
#
#    Urban Pop % World Share
# 20        83 %      0.87 %

# %%
#check interestings stats of Italy
countries[countries['Country (or dependency)'] == 'Italy']
#60 million population, 206 P/km2, med age 47, urban pop 69%
# Out:
#    Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 22                   Italy           60446035       -0.15 %      -88249
#
#     Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 22              206           294140        148943.0        1.3       47
#
#    Urban Pop % World Share
# 22        69 %      0.78 %

# %%
#check interestings stats of Romania
countries[countries['Country (or dependency)'] == 'Romania']
#19 million population, 84 P/km2, med age 43, urban pop 55%
# Out:
#    Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 60                 Romania           19214608       -0.66 %     -126866
#
#     Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 60               84           230170        -73999.0        1.6       43
#
#    Urban Pop % World Share
# 60        55 %      0.25 %

# %%
#check interestings stats of South Korea
countries[countries['Country (or dependency)'] == 'South Korea']
#51 million population, 527 P/km2, med age 44, urban pop 82%
# Out:
#    Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 27             South Korea           51276977        0.09 %       43877
#
#     Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 27              527            97230         11731.0        1.1       44
#
#    Urban Pop % World Share
# 27        82 %      0.66 %

# %%
df2 = countries[['Country (or dependency)', 'Population (2020)', 'Density (P/Km²)', 'Med. Age', 'Urban Pop %']]
df2 = df2[df2['Country (or dependency)'].isin(['Brazil', 'India', 'Italy', 'Netherlands', 'Romania', 'South Korea', 'Turkey', 'United Kingdom'])]
df2
# Out:
#    Country (or dependency)  Population (2020)  Density (P/Km²) Med. Age  \
# 1                    India         1382345085              464       28
# 5                   Brazil          212821986               25       33
# 16                  Turkey           84495243              110       32
# 20          United Kingdom           67948282              281       40
# 22                   Italy           60446035              206       47
# 27             South Korea           51276977              527       44
# 60                 Romania           19214608               84       43
# 68             Netherlands           17141544              508       43
#
#    Urban Pop %
# 1         35 %
# 5         88 %
# 16        76 %
# 20        83 %
# 22        69 %
# 27        82 %
# 60        55 %
# 68        92 %

# %%
#figure of population density (TO DO: sort by population density)
fig, ax = plt.subplots(figsize=(16, 6))
plt.xticks(rotation = 45)
sns.barplot(data = df2, x = 'Country (or dependency)', y = 'Population (2020)')
# Out:
# <AxesSubplot:xlabel='Country (or dependency)', ylabel='Population (2020)'>

# %%
#figure of population density (TO DO: sort by population density)
fig, ax = plt.subplots(figsize=(16, 6))
plt.xticks(rotation = 45)
sns.barplot(data = df2, x = 'Country (or dependency)', y = 'Density (P/Km²)')
# Out:
# <AxesSubplot:xlabel='Country (or dependency)', ylabel='Density (P/Km²)'>

# %%
#figure of population density (TO DO: sort by Med Age)
fig, ax = plt.subplots(figsize=(16, 6))
plt.xticks(rotation = 45)
sns.barplot(data = df2, x = 'Country (or dependency)', y = 'Med. Age')
# Out:
# <AxesSubplot:xlabel='Country (or dependency)', ylabel='Med. Age'>

# %%
#figure of population density (TO DO: sort by Urban Population)
fig, ax = plt.subplots(figsize=(16, 6))
plt.xticks(rotation = 45)
sns.barplot(data = df2, x = 'Country (or dependency)', y = 'Urban Pop %')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-dca46e43bdb9> in <module>
#       2 fig, ax = plt.subplots(figsize=(16, 6))
#       3 plt.xticks(rotation = 45)
# ----> 4 sns.barplot(data = df2, x = 'Country (or dependency)', y = 'Urban Pop %')
#
# /usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3142             ax=None, **kwargs):
#    3143
# -> 3144     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3145                           estimator, ci, n_boot, units, seed,
#    3146                           orient, color, palette, saturation,
#
# ...
