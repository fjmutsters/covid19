# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import plotly.express as px
#import theme

# %matplotlib inline

# %%
COVID_CONFIRMED_URL = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'

covid_confirmed = pd.read_csv(COVID_CONFIRMED_URL)

print(covid_confirmed.shape)

covid_confirmed.head()
# Out:
# (266, 268)
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  10/2/20  10/3/20  10/4/20  \
# 0        0        0        0        0  ...    39290    39297    39341
# 1        0        0        0        0  ...    13965    14117    14266
# 2        0        0        0        0  ...    51847    51995    52136
# 3        0        0        0        0  ...     2110     2110     2110
# 4        0        0        0        0  ...     5211     5370     5402
#
#    10/5/20  10/6/20  10/7/20  10/8/20  10/9/20  10/10/20  10/11/20
# 0    39422    39486    39548    39616    39693     39703     39799
# 1    14410    14568    14730    14899    15066     15231     15399
# 2    52270    52399    52520    52658    52804     52940     53072
# 3     2370     2370     2568     2568     2696      2696      2696
# 4     5530     5725     5725     5958     6031      6246      6366
#
# [5 rows x 268 columns]

# %%
covid_confirmed.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '10/2/20', '10/3/20', '10/4/20', '10/5/20', '10/6/20', '10/7/20',
#        '10/8/20', '10/9/20', '10/10/20', '10/11/20'],
#       dtype='object', length=268)

# %%
COVID_DEATHS_URL = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv'

covid_deaths = pd.read_csv(COVID_DEATHS_URL)

print(covid_confirmed.shape)

covid_deaths.head()
# Out:
# (266, 268)
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  10/2/20  10/3/20  10/4/20  \
# 0        0        0        0        0  ...     1458     1462     1462
# 1        0        0        0        0  ...      389      392      396
# 2        0        0        0        0  ...     1749     1756     1760
# 3        0        0        0        0  ...       53       53       53
# 4        0        0        0        0  ...      189      193      195
#
#    10/5/20  10/6/20  10/7/20  10/8/20  10/9/20  10/10/20  10/11/20
# 0     1466     1467     1469     1470     1472      1473      1477
# 1      400      403      407      411      413       416       420
# 2     1768     1768     1771     1783     1789      1795      1801
# 3       53       53       53       54       55        55        55
# 4      199      211      211      208      212       218       218
#
# [5 rows x 268 columns]

# %%
COVID_RECOVERED_URL = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv'

covid_recovered = pd.read_csv(COVID_RECOVERED_URL)

print(covid_recovered.shape)

covid_recovered.head()
# Out:
# (253, 268)
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  10/2/20  10/3/20  10/4/20  \
# 0        0        0        0        0  ...    32842    32842    32852
# 1        0        0        0        0  ...     8342     8536     8675
# 2        0        0        0        0  ...    36385    36482    36578
# 3        0        0        0        0  ...     1540     1540     1540
# 4        0        0        0        0  ...     2215     2436     2577
#
#    10/5/20  10/6/20  10/7/20  10/8/20  10/9/20  10/10/20  10/11/20
# 0    32879    32977    33045    33058    33058     33064     33114
# 1     8825     8965     9115     9215     9304      9406      9500
# 2    36672    36763    36857    36958    37067     37170     37170
# 3     1615     1615     1715     1715     1814      1814      1814
# 4     2591     2598     2598     2635     2685      2716      2743
#
# [5 rows x 268 columns]

# %%
covid_confirmed[['Province/State']] = covid_confirmed[['Province/State']].fillna('')
covid_confirmed.fillna(0, inplace=True)

covid_deaths[['Province/State']] = covid_deaths[['Province/State']].fillna('')
covid_deaths.fillna(0, inplace=True)

covid_recovered[['Province/State']] = covid_recovered[['Province/State']].fillna('')
covid_recovered.fillna(0, inplace=True)

# %%
#check if NaN gone
covid_confirmed.isna().sum().sum()
# Out:
# 0

# %%
#NL confirmed
covid_confirmed_NL = covid_confirmed[(covid_confirmed['Country/Region'] == 'Netherlands') & (covid_confirmed['Province/State'] == '')]
covid_confirmed_NL
#&
# Out:
#     Province/State Country/Region      Lat    Long  1/22/20  1/23/20  1/24/20  \
# 190                   Netherlands  52.1326  5.2913        0        0        0
#
#      1/25/20  1/26/20  1/27/20  ...  10/2/20  10/3/20  10/4/20  10/5/20  \
# 190        0        0        0  ...   127922   131889   135892   135892
#
#      10/6/20  10/7/20  10/8/20  10/9/20  10/10/20  10/11/20
# 190   144999   149988   155810   161781    168280    174653
#
# [1 rows x 268 columns]

# %%
#NL deaths
covid_deaths_NL = covid_deaths[(covid_deaths['Country/Region'] == 'Netherlands') & (covid_deaths['Province/State'] == '')]
covid_deaths_NL
# Out:
#     Province/State Country/Region      Lat    Long  1/22/20  1/23/20  1/24/20  \
# 190                   Netherlands  52.1326  5.2913        0        0        0
#
#      1/25/20  1/26/20  1/27/20  ...  10/2/20  10/3/20  10/4/20  10/5/20  \
# 190        0        0        0  ...     6428     6449     6454     6454
#
#      10/6/20  10/7/20  10/8/20  10/9/20  10/10/20  10/11/20
# 190     6482     6518     6531     6544      6567      6584
#
# [1 rows x 268 columns]

# %%
#NL recovered
covid_recovered_NL = covid_recovered[(covid_recovered['Country/Region'] == 'Netherlands') & (covid_recovered['Province/State'] == '')]
covid_recovered_NL
# Out:
#     Province/State Country/Region      Lat    Long  1/22/20  1/23/20  1/24/20  \
# 177                   Netherlands  52.1326  5.2913        0        0        0
#
#      1/25/20  1/26/20  1/27/20  ...  10/2/20  10/3/20  10/4/20  10/5/20  \
# 177        0        0        0  ...        0        0        0        0
#
#      10/6/20  10/7/20  10/8/20  10/9/20  10/10/20  10/11/20
# 177        0        0        0        0         0         0
#
# [1 rows x 268 columns]

# %%
#nr confiremd cases NL
covid_confirmed_NL_count = covid_confirmed_NL.iloc[:, 4:].sum().max()
covid_confirmed_NL_count
# Out:
# 174653

# %%
covid_deaths_NL_count = covid_deaths_NL.iloc[:, 4:].sum().max()
covid_deaths_NL_count
# Out:
# 6584

# %%
# percentage died compared to cases
covid_deaths_NL_count/covid_confirmed_NL_count
# Out:
# 0.037697606110401766

# %%
#no NL data availabe about recovered
covid_recovered_NL_count = covid_recovered_NL.iloc[:, 4:].sum().max()
covid_recovered_NL_count
# Out:
# 0

# %%
covid_NL_confirmed = covid_confirmed_NL.iloc[:, 4:].sum(axis=0)

covid_NL_confirmed.tail()
# Out:
# 10/7/20     149988
# 10/8/20     155810
# 10/9/20     161781
# 10/10/20    168280
# 10/11/20    174653
# dtype: int64

# %%
covid_NL_deaths = covid_deaths_NL.iloc[:, 4:].sum(axis=0)

covid_NL_deaths.tail()
# Out:
# 10/7/20     6518
# 10/8/20     6531
# 10/9/20     6544
# 10/10/20    6567
# 10/11/20    6584
# dtype: int64

# %%
fig, ax = plt.subplots(figsize=(16, 6))

sns.lineplot(x=covid_NL_confirmed.index, y=covid_NL_confirmed, sort=False, linewidth=2)
sns.lineplot(x=covid_NL_deaths.index, y=covid_NL_deaths, sort=False, linewidth=2)

ax.lines[0].set_linestyle("--")

plt.suptitle("COVID-19 NL cases over the time evolution", fontsize=16, fontweight='bold', color='white')

plt.xticks(rotation=45)
plt.ylabel('Number of cases')

ax.legend(['Confirmed', 'Deaths'])

plt.show()

# %%
fig, ax = plt.subplots(figsize=(16, 6))
ax.set(yscale="log")
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))

sns.lineplot(x=covid_NL_confirmed.index, y=covid_NL_confirmed, sort=False, linewidth=2)
sns.lineplot(x=covid_NL_deaths.index, y=covid_NL_deaths, sort=False, linewidth=2)

ax.lines[0].set_linestyle("--")

plt.suptitle("COVID-19 NL cases over the time", fontsize=16, fontweight='bold', color='white')
plt.title("(logarithmic scale)", color='white')

plt.xticks(rotation=45)
plt.ylabel('Number of cases')

ax.legend(['Confirmed', 'Deaths'])

plt.show()
